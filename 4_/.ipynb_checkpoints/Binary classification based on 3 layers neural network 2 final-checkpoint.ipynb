# %% [markdown]
# $$\ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ 20165549\ \ JANG\ \ JAE\ \ YONG$$

# %% [markdown]
# Build a binary classifier based on 3 layers neural network using the human versus horse dataset

# %%
import matplotlib.pyplot as plt
import numpy as np

import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torchvision
import os
import pandas as pd

transform = transforms.Compose([#transforms.Resize((256,256)),  
                                transforms.Grayscale(),
    # the code transforms.Graysclae() is for changing the size [3,100,100] to [1, 100, 100] (notice : [channel, height, width] )
                                transforms.ToTensor(),])

#train_data_path = 'relative path of training data set'
train_data_path = 'horse-or-human/horse-or-human/train'
trainset = torchvision.datasets.ImageFolder(root=train_data_path, transform=transform)
# change the valuse of batch_size, num_workers for your program
# if shuffle=True, the data reshuffled at every epoch 
trainloader = torch.utils.data.DataLoader(trainset, batch_size=1, shuffle=False, num_workers=1)  

validation_data_path = 'horse-or-human/horse-or-human/validation'
valset = torchvision.datasets.ImageFolder(root=validation_data_path, transform=transform)
# change the valuse of batch_size, num_workers for your program
valloader = torch.utils.data.DataLoader(valset, batch_size=1, shuffle=False, num_workers=1)  

NUM_EPOCH = range(1) # my code

#
# Image size and number of data
#
image_size = 10000
train_count = 1027
validation_count = 256

train_label = np.empty(train_count, dtype=float)
train_data = np.ones((train_count, image_size), dtype=float)

validation_label = np.empty(validation_count, dtype=float)
validation_data = np.ones((validation_count, image_size), dtype=float)

for epoch in (NUM_EPOCH):
    # load training images of the batch size for every iteration
    for i, data in enumerate(trainloader):

        # inputs is the image
        # labels is the class of the image
        inputs, labels = data

        # if you don't change the image size, it will be [batch_size, 1, 100, 100]
        #print(inputs.shape)

        # if labels is horse it returns tensor[0,0,0] else it returns tensor[1,1,1]
        #print(labels)
        
        train_label[i] = int(labels)
        train_tmp = np.asfarray(inputs)
        train_data[i, :10000] = train_tmp[0, 0, :, :].reshape(10000)
        
    # load validation images of the batch size for every iteration
    for i, data in enumerate(valloader):
        
        # inputs is the image
        # labels is the class of the image
        inputs, labels = data

        # if you don't change the image size, it will be [batch_size, 1, 100, 100]
        #print(inputs.shape)

        # if labels is horse it returns tensor[0,0,0] else it returns tensor[1,1,1]
        #print(labels)
        
        validation_label[i] = int(labels)
        validation_tmp = np.asfarray(inputs)
        validation_data[i, :10000] = validation_tmp[0, 0, :, :].reshape(10000)

# %%
iteration = 1000 # Max Iteration
delta = 10**(-9)

loss_arr = np.zeros(iteration, dtype=float)
t_loss_arr = np.zeros(iteration, dtype=float)
loss_value_arr = np.zeros(iteration, dtype=float)
t_loss_value_arr = np.zeros(iteration, dtype=float)

def sigmoid(x):
    return 1/(1 + np.exp(-x))

def loss_function(t, y):
    return -np.sum(t*np.log(y+delta) + (1-t)*np.log(1-y+delta))

# %%
def tanh(x):
    return (np.exp(x) - np.exp(-x)) / (np.exp(x) + np.exp(-x) + delta)

def ReLU(x):
    return np.maximum(0, x)

def LeakyReLU(x):
    return np.maximum(0.1*x, x)

# %%
def ActivationFunc(FunctionName, x):
    
    if FunctionName == 'sigmoid':
        return sigmoid(x)
    elif FunctionName == 'tanh':
        return tanh(x)
    elif FunctionName == 'ReLU':
        return ReLU(x)
    elif FunctionName == 'LeakyReLU':
        return LeakyReLU(x)

# %%
def d_ActivationFunc(FunctionName, x):
    
    if FunctionName == 'sigmoid':
        return sigmoid(x) * (1 - sigmoid(x))
    elif FunctionName == 'tanh':
        return 1 - (tanh(x))**2
    elif FunctionName == 'ReLU':
        return 1. * (x > 0)
    elif FunctionName == 'LeakyReLU':
        return 1. * (x > 0) + 0.1 * (x < 0)

# %%
def ThreeLayerNeuralNetwork(FuncName):
    
    learningRate = 10**(-4) # learningRate
    
    uc = 20   # u
    vc = 20   # v
    wc = 1   # w

    a = np.ones((train_count, uc), dtype=float)
    b = np.ones((train_count, vc), dtype=float)
    c = np.ones((train_count, wc), dtype=float)
    h = np.ones((train_count, wc), dtype=float)
    
    t_a = np.ones((train_count, uc), dtype=float)
    t_b = np.ones((train_count, vc), dtype=float)
    t_c = np.ones((train_count, wc), dtype=float)
    t_h = np.ones((train_count, wc), dtype=float)

    u = np.random.randn(image_size, uc) / np.sqrt(image_size)
    v = np.random.randn(uc, vc) / np.sqrt(uc)
    w = np.random.randn(vc) / np.sqrt(vc)
    
    b1 = np.random.rand(uc)
    b2 = np.random.rand(vc)
    b3 = np.random.rand(wc)
    
    d_lc = np.empty(train_count, dtype=float)
    
    for iter in range(iteration):
        
        #
        # training matrix
        
        a = (train_data).dot(u) + b1
        b = (ActivationFunc(FuncName, a)).dot(v) + b2
        c = (ActivationFunc(FuncName, b)).dot(w) + b3
        h = sigmoid(c)

        #
        # validation matrix for loss value calculation
        t_a = (validation_data).dot(u) #+ b1
        t_b = (ActivationFunc(FuncName, t_a)).dot(v) #+ b2
        t_c = (ActivationFunc(FuncName, t_b)).dot(w) #+ b3
        t_h = sigmoid(t_c)

        ## derivation
        d_lc = h - train_label
        
        loss3 = d_lc * d_ActivationFunc(FuncName, c)
        loss2 = ((loss3.reshape(train_count, 1)).dot(w.reshape(1, vc))) * (d_ActivationFunc(FuncName, b))
        loss1 = loss2.dot(v.T) * d_ActivationFunc(FuncName, a)

        w = w - learningRate * ((ActivationFunc(FuncName, b)).T).dot(loss3)
        b3 = b3 - learningRate * loss3
        v = v - learningRate * ((ActivationFunc(FuncName, a)).T).dot(loss2)
        b2 = b2 - learningRate * loss2
        u = u - learningRate * ((ActivationFunc(FuncName, train_data)).T).dot(loss1)
        b1 = b1 - learningRate * loss1

       
        loss_value = np.sum(loss_function(train_label, h))
        t_loss_value = np.sum(loss_function(validation_label, t_h))
        training_loss = np.sum(np.abs(train_label- h) > 0.5)
        testing_loss = np.sum(np.abs(validation_label- t_h) > 0.5)
        
        if iter % 50 == 0 or iter+1 == iteration:                           ###
            print("iter =", iter)                                               ##
            print("train loss count =", training_loss)                           ##
            print("train loss value =", loss_value / train_count)                ##
            print("validation loss count =", testing_loss)                       ##
            print("validation loss value =", t_loss_value / validation_count)   ##

        loss_value_arr[iter] = loss_value
        t_loss_value_arr[iter] = t_loss_value
        loss_arr[iter] = training_loss
        t_loss_arr[iter] = testing_loss
        
        if loss_value < 0.1:
            break
    
    LossPlot(FuncName)
    AccuracyPlot(FuncName)
    Loss_And_Accuracy_Table(FuncName)
            
    return loss_value_arr, loss_arr, t_loss_value_arr, t_loss_arr

# %%
def LossPlot(FuncName):
    x = range(iteration)
    y1 = loss_value_arr[x] / train_count
    y2 = t_loss_value_arr[x] / validation_count

    plt.plot(x, y1, "BLUE", label='$Train Data$')
    plt.plot(x, y2, "RED", label='$Validation Data$')
    plt.title(FuncName + ' Training and Validation Loss')
    plt.xlabel('Iteration')
    plt.ylabel('Loss')
    plt.show()

# %%
def AccuracyPlot(FuncName):
    x = range(iteration)
    y1 = (train_count - loss_arr[x]) / train_count
    y2 = (validation_count - t_loss_arr[x]) / validation_count

    plt.plot(x, y1, "BLUE", label='$Train Data$')
    plt.plot(x, y2, "RED", label='$Validation Data$')
    plt.title(FuncName + ' Training and Validation Accuracy')
    plt.xlabel('Iteration')
    plt.ylabel('Accuracy percent')
    plt.show()

# %%
def Loss_And_Accuracy_Table(FuncName):
    print(FuncName + ' Loss and Accuracy Table')
    idx1 = round(loss_value_arr[iteration - 1] / train_count, 6)
    idx2 = str(round((train_count - loss_arr[iteration - 1]) / train_count * 100, 2)) + ' %'
    idx3 = round(t_loss_value_arr[iteration - 1] / validation_count, 6)
    idx4 = str(round((validation_count - t_loss_arr[iteration - 1]) / validation_count * 100, 2)) + ' %'

    df = pd.DataFrame(data=np.array([[idx1, idx2], [idx3, idx4]]), index= ['Training', 'Validation'], columns=['Loss', 'Accuracy'])
    display(df)

# %%
ThreeLayerNeuralNetwork('sigmoid')
# Out:
# iter = 0
# train loss count = 500
# train loss value = 0.6962439357335969
# validation loss count = 128
# validation loss value = 0.695955655923552
# iter = 50
# train loss count = 500
# train loss value = 0.6922180045677089
# validation loss count = 128
# validation loss value = 0.6917908034666869
# iter = 100
# train loss count = 500
# train loss value = 0.690059951905001
# validation loss count = 128
# validation loss value = 0.6889179902017475
# iter = 150
# train loss count = 498
# train loss value = 0.6883188774857097
# validation loss count = 128
# validation loss value = 0.6864653808796229
# iter = 200
# train loss count = 484
# train loss value = 0.6864335386089783
# validation loss count = 128
# validation loss value = 0.6837613195108267
# iter = 250
# train loss count = 452
# train loss value = 0.6844795788420399
# validation loss count = 128
# validation loss value = 0.6811588895756806
# iter = 300
# train loss count = 403
# train loss value = 0.6824587590783388
# validation loss count = 128
# validation loss value = 0.6784362323374822
# iter = 350
# train loss count = 367
# train loss value = 0.6802557883934286
# validation loss count = 128
# validation loss value = 0.6753993426641833
# iter = 400
# train loss count = 343
# train loss value = 0.677807170010927
# validation loss count = 128
# validation loss value = 0.6719945695224887
# iter = 450
# train loss count = 327
# train loss value = 0.6750712184792826
# validation loss count = 128
# validation loss value = 0.66817078487305
# iter = 500
# train loss count = 309
# train loss value = 0.6720128935473558
# validation loss count = 120
# validation loss value = 0.663871320516831
# iter = 550
# train loss count = 294
# train loss value = 0.6685984507685058
# validation loss count = 111
# validation loss value = 0.6590399486826042
# iter = 600
# train loss count = 285
# train loss value = 0.6647937947453038
# validation loss count = 107
# validation loss value = 0.6536223860798209
# iter = 650
# train loss count = 279
# train loss value = 0.6605646750137074
# validation loss count = 105
# validation loss value = 0.6475666314211974
# iter = 700
# train loss count = 274
# train loss value = 0.6558779550853355
# validation loss count = 105
# validation loss value = 0.6408243564096696
# iter = 750
# train loss count = 271
# train loss value = 0.6507035995607394
# validation loss count = 102
# validation loss value = 0.6333534418118199
# iter = 800
# train loss count = 262
# train loss value = 0.6450171575391057
# validation loss count = 98
# validation loss value = 0.6251210526965241
# iter = 850
# train loss count = 257
# train loss value = 0.6388024757304717
# validation loss count = 90
# validation loss value = 0.6161066904172999
# iter = 900
# train loss count = 256
# train loss value = 0.6320541307935119
# validation loss count = 84
# validation loss value = 0.6063046770059998
# iter = 950
# train loss count = 252
# train loss value = 0.6247785416718772
# validation loss count = 77
# validation loss value = 0.5957262767454725
# iter = 999
# train loss count = 248
# train loss value = 0.6171529655005397
# validation loss count = 73
# validation loss value = 0.5846408717173233
# sigmoid Loss and Accuracy Table
#                 Loss Accuracy
# Training    0.617153  75.85 %
# Validation  0.584641  71.48 %
# (array([715.042522  , 714.66752788, 714.37197597, 714.13769006,
#         713.95040695, 713.79896883, 713.67467014, 713.57073601,
#         713.48190893, 713.40412249, 713.33424463, 713.26987578,
#         713.20919032, 713.15081195, 713.09371585, 713.03715158,
#         712.98058252, 712.923638  , 712.86607558, 712.80775125,
#         712.74859575, 712.688596  , 712.6277802 , 712.56620624,
#         712.50395241, 712.44111026, 712.37777886, 712.31406055,
#         712.25005756, 712.18586957, 712.12159191, 712.0573143 ,
#         711.99312001, 711.92908541, 711.86527974, 711.80176508,
#         711.73859656, 711.67582254, 711.61348503, 711.55162003,
#         711.49025799, 711.42942425, 711.36913946, 711.30942005,
#         711.25027863, 711.19172442, 711.13376358, 711.07639964,
#         711.01963373, 710.96346497, 710.90789069, 710.85290671,
#         710.79850752, 710.74468653, 710.69143624, 710.63874835,
#         710.58661397, 710.53502369, 710.48396772, 710.43343598,
#         710.38341815, 710.33390378, 710.28488233, 710.23634321,
#         710.18827585, 710.1406697 , 710.09351429, 710.04679922,
#         710.00051423, 709.95464914, 709.90919391, 709.86413866,
#         709.8194736 , 709.77518914, 709.73127577, 709.68772417,
#         709.64452513, 709.60166958, 709.55914858, 709.51695331,
#         709.47507507, 709.43350529, 709.39223548, 709.3512573 ,
#         709.31056246, 709.27014281, 709.22999026, 709.19009682,
#         709.1504546 , 709.11105577, 709.07189258, 709.03295738,
#         708.99424256, 708.95574062, 708.9174441 , 708.87934562,
#         708.84143789, 708.80371366, 708.76616575, 708.72878708,
#         708.69157061, 708.65450936, 708.61759645, 708.58082505,
#          81.,  80.,  79.,  79.,  79.,  79.,  79.,  78.,  78.,  78.,  78.,
#          78.,  78.,  78.,  78.,  77.,  77.,  76.,  76.,  76.,  75.,  75.,
#          75.,  75.,  75.,  75.,  75.,  75.,  75.,  75.,  75.,  75.,  75.,
#          75.,  75.,  75.,  75.,  75.,  75.,  76.,  76.,  75.,  74.,  74.,
#          74.,  74.,  74.,  74.,  73.,  73.,  73.,  73.,  73.,  73.,  73.,
#          73.,  72.,  73.,  73.,  73.,  73.,  73.,  73.,  73.,  73.]))

# %% [markdown]
# MarkDown :

# %% [markdown]
# | Dataset | Loss | Accuracy |
# |:--------|:--------:|--------:|
# | Training | 0.670634 | 58.71% |
# | Validation | 0.615124 | 69.53% |

# %%
ThreeLayerNeuralNetwork('tanh')
LossPlot('tanh')
AccuracyPlot('tanh')
Loss_And_Accuracy_Table('tanh')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-273-6a6fb90fd150> in <module>
# ----> 1 ThreeLayerNeuralNetwork('tanh')
#       2 LossPlot('tanh')
#       3 AccuracyPlot('tanh')
#       4 Loss_And_Accuracy_Table('tanh')
#
# <ipython-input-272-c97bfa66b5d6> in ThreeLayerNeuralNetwork(FuncName)
#      42         for i in range(train_count): # u * X
#      43             for j in range(uc):
# ---> 44                 a[i, j] = (train_data[i, :]).dot(u[:, j])
#      45
#      46         for i in range(train_count): # v * ActivationFunc(a)
#
# ValueError: shapes (10000,) and (10001,) not aligned: 10000 (dim 0) != 10001 (dim 0)

# %% [markdown]
# | Dataset | Loss | Accuracy |
# |:--------|:--------:|--------:|
# | Training | 0.670634 | 58.71% |
# | Validation | 0.615124 | 69.53% |

# %%
ThreeLayerNeuralNetwork('ReLU')
LossPlot('ReLU')
AccuracyPlot('ReLU')
Loss_And_Accuracy_Table('ReLU')
# Out:
# ReLU Loss and Accuracy Table
#            Loss Accuracy
# Training    0.0  100.0 %
# Validation  0.0  100.0 %

# %% [markdown]
# | Dataset | Loss | Accuracy |
# |:--------|:--------:|--------:|
# | Training | 0.670634 | 58.71% |
# | Validation | 0.615124 | 69.53% |

# %%
ThreeLayerNeuralNetwork('LeakyReLU')
LossPlot('LeakyReLU')
AccuracyPlot('LeakyReLU')
Loss_And_Accuracy_Table('LeakyReLU')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-275-c4d1084ab40b> in <module>
# ----> 1 ThreeLayerNeuralNetwork('LeakyReLU')
#       2 LossPlot('LeakyReLU')
#       3 AccuracyPlot('LeakyReLU')
#       4 Loss_And_Accuracy_Table('LeakyReLU')
#
# <ipython-input-272-c97bfa66b5d6> in ThreeLayerNeuralNetwork(FuncName)
#      42         for i in range(train_count): # u * X
#      43             for j in range(uc):
# ---> 44                 a[i, j] = (train_data[i, :]).dot(u[:, j])
#      45
#      46         for i in range(train_count): # v * ActivationFunc(a)
#
# ValueError: shapes (10000,) and (10001,) not aligned: 10000 (dim 0) != 10001 (dim 0)

# %% [markdown]
# | Dataset | Loss | Accuracy |
# |:--------|:--------:|--------:|
# | Training | 0.670634 | 58.71% |
# | Validation | 0.615124 | 69.53% |
